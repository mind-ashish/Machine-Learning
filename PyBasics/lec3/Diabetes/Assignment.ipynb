# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn import datasets
d=datasets.load_diabetes()

# %%
d
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990842, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06832974, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286377, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04687948,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452837, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00421986,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
import pandas as pd
diab= pd.read_csv("training_diabetes_x_y_train (1).csv")
# Out:
#         # age       sex       bmi        bp        s1        s2        s3  \
# 10   0.030811 -0.044642 -0.033151 -0.022885 -0.046975 -0.081167  0.103865
# 160  0.012648 -0.044642 -0.025607 -0.040099 -0.030464 -0.045155  0.078093
# 265  0.059871 -0.044642 -0.000817 -0.084857  0.075484  0.079478  0.004460
# 279  0.048974  0.050680  0.088642  0.087287  0.035582  0.021546 -0.024993
# 171 -0.070900 -0.044642  0.092953  0.012691  0.020446  0.042527  0.000779
# 110 -0.030942 -0.044642  0.046607  0.014987 -0.016704 -0.047034  0.000779
# 65   0.041708  0.050680 -0.014828 -0.017147 -0.005697  0.008394 -0.013948
# 87  -0.034575  0.050680 -0.055785 -0.015999 -0.009825 -0.007890  0.037595
# 300 -0.070900 -0.044642  0.039062 -0.033214 -0.012577 -0.034508 -0.024993
# 250  0.045341 -0.044642  0.039062  0.045972  0.006687 -0.024174  0.008142
#
#            s4        s5        s6      Y
# 10  -0.076395 -0.039810 -0.054925   65.0
# 160 -0.076395 -0.072128  0.011349   98.0
# ...
