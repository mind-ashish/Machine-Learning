# %%
import pandas as pd
a=pd.read_csv("annual-enterprise-survey-2017-financial-year-provisional-csv.csv")

# %%
a.sample(20)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 19399  2013                     Level 4                CC511
# 4311   2017                     Level 1                   RS
# 21019  2013                     Level 4                GH134
# 22168  2013                     Level 3                 MN21
# 15004  2014                     Level 4                CC531
# 11330  2015                     Level 4                FF111
# 1162   2017                     Level 4                CC611
# 17965  2014                     Level 4                RS111
# 21570  2013                     Level 3                 JJ12
# 21793  2013                     Level 4                LL123
# 6447   2016                     Level 4                EE113
# 14112  2014                     Level 3                 AA13
# 21780  2013                     Level 4                LL123
# 1111   2017                     Level 3                 CC53
# ...

# %%
a.iloc[1:2,2:5]
# Out:
#   Industry_code_NZSIOC Industry_name_NZSIOC               Units
# 1                99999     All industries    Dollars (millions)

# %%
a.shape
# Out:
# (23175, 10)
