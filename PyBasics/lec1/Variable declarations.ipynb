# %%
#Variables, ctrl enter, option enter, shift M
a=3
a=2
a
a=3.4
a
a=-12333333333333.4444444
a

a='abc'
a
print(a)
a="defg"
print(a)
a='c'
print(a)

b=5
print(id(b))
b=12
print(id(b))
c=5
print(id(c))

#range: -5 to 256 for optimisation
d=257
e=257
print(id(d)) 
print(id(e))

a,b= 3,4
print(a)
print(b)

#swapping
a,b= b,a

print(a)
print(b)

#complex nos
a= 3+4j
print(a)
# print(id(a))
print(type(a))

#Strings & chars: chars are single length strings only
str='hello'
print(str)
str2="hello"
print(str)
ch='h'
print(ch)
print(type(str))
print(type(str2))
print(type(ch))

print(str[2])
# str[2]='o' not allowed

#ascii values
i= ord('a')  #ord takes single length string as input, i.e char only
print(i)  #print int value corresponding to char 'a'


i=97
ch=chr(i)  #chr() return char corresponding to ascii value.
print(ch)

#a=2,b=3,c=5 this way is wrong in python
a,b,c =2,3,5
print(a)
print(b)
print(c)
# Out:
# abc
# defg
# c
# 4418614512
# 4418614736
# 4418614512
# 4460230768
# 4460231888
# 3
# 4
# 4
# 3
# (3+4j)
# <class 'complex'>
# hello
# hello
# h
# <class 'str'>
# <class 'str'>
# <class 'str'>
# l
# 97
# a
# 2
# 3
# 5
