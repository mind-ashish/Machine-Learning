# %%
#operators
a=2
b=3
a+b, a-b, a*b, a/b  #can do multiple operation in same line

#a/b gives float. for int type use //
a//b   #for int a/b
a**b  #for a power b
a^b, a&b, a|b, ~a #bitwise XOR,AND,OR,NOT

#boolean values: use True,False
d=True
d
e=False
e

#Strngs
str1="abcd"
print(len(str1)) #len() gives length of string, array, list etc.

str1+"ef" #append
print(str1)
print(id(str1))
str1=str1+"ef" #to reflect change in str
print(str1)
print(id(str1))  #id is diff means new string value on new memory is given , preious str not changed

#str+5 #not allowed
str1+ '5'#concat 5 in str form
str1*5  #does repeat it 5 time

str1.upper()
hold= str1.isalpha()
print(hold)

hold= str1.isdigit()
print(hold)

hold= str1.startswith("ab")
print(hold)

##split 
str="hello world python 3"
print(str)
l=str.split()  #return array of space separated split
print(l)


l= ",".join(l) #to join around ", &to reflect change in l also
print(l)


l=str.split()
l=" ".join(l)  #rejoin around space
print(l)


l=str.split()
l="-".join(l)  #rejoin around -
print(l)


###substrings
str='hello america'
print(str)
temp= str[0:3] #start-end, end index not included
print(temp)

temp=str
temp= str[:]  #all string
print(temp)

temp=str
temp= str[::]  #all string
print(temp)

temp=str[1] #copy ith char of str. not a substr fn.
print(temp)

temp=str[1:]  #index 1 to end
print(temp)

temp=str
temp=str[:5]  #from start to 4th index
print(temp)

temp=str
temp=str[0:8:2]  #from start to 7th index,while choose 2 step at a time ie with gap of 1 char
print(temp)


temp=str
temp=str[-5:-2]   #start=2,end=5 indexing done from right to left,print usual manner(l to r)
print(temp)


temp=str
temp=str[8:1:-1]  #start=2,end=5 indexing done from right to left & print in rev manner.
print(temp)
# Out:
# 4
# abcd
# 4404836872
# abcdef
# 4409334728
# True
# False
# True
# hello world python 3
# ['hello', 'world', 'python', '3']
# hello,world,python,3
# hello world python 3
# hello-world-python-3
# hello america
# hel
# hello america
# hello america
# e
# ello america
# hello
# hloa
# eri
# ema oll
